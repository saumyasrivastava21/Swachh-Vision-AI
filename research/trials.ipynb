# %%
import gdown
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\saums\\OneDrive\\Desktop\\COMPUTER VISION\\Swachh-Vision-AI'

# %%
url ="https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61&confirm=t&uuid=9526c524-55e3-4995-a3c5-9e45817962db
# To: c:\Users\saums\OneDrive\Desktop\COMPUTER VISION\Swachh-Vision-AI\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:03<00:00, 12.1MB/s]
# 'data/waste_data.zip'

# %%
# %pwd
# Out:
# 'c:\\Users\\saums\\OneDrive\\Desktop\\COMPUTER VISION\\Swachh-Vision-AI'
